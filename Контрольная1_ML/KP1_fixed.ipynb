# %%
#!pip install numpy
#!pip install matplotlib
#!pip install pandas

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
df = pd.read_excel('19.xlsx', sep=';')

# %%
df
# Out:
#     Площадь загальна кв.м  Этаж  Количество сотрудников в штаті       Тип  \
# 0                    9.00     1                               2     Light
# 1                   30.00     1                               2     Light
# 2                   15.00     1                               2     light
# 3                   20.00     1                               2     light
# 4                   30.00     1                               2     light
# ..                    ...   ...                             ...       ...
# 64                  51.77     1                               6  Standart
# 65                  27.26     1                               4     Light
# 66                 148.91     1                               2     Light
# 67                  50.93     1                               3  Standart
# 68                  30.00     1                               3     light
#
#     Кількість відгуків в гуглі  Количество чеков в месяц  Средний чек  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Площадь загальна кв.м           69 non-null     float64
#  1   Этаж                            69 non-null     int64
#  2   Количество сотрудников в штаті  69 non-null     int64
#  3   Тип                             69 non-null     object
#  4   Кількість відгуків в гуглі      39 non-null     float64
#  5   Количество чеков в месяц        69 non-null     float64
#  6   Средний чек                     62 non-null     float64
#  7   Середній дохід населення        64 non-null     float64
#  8   Населення середнє               64 non-null     float64
#  9   Спеціалізований хліб            69 non-null     int64
#  10  Спеціалізоване м'ясо            69 non-null     int64
#  11  Спеціалізований сир             69 non-null     int64
# ...

# %%
#Visualization
# Feature distribution
df['Середній дохід населення'].plot(kind = 'hist')

# %%
df['Количество чеков в месяц'].plot(kind = 'hist')

# %%
df['Количество сотрудников в штаті'].plot(kind = 'hist')

# %%
#Statistics
df.describe()
# Out:
#        Площадь загальна кв.м  Этаж  Количество сотрудников в штаті  \
# count              69.000000  69.0                       69.000000
# mean               47.412725   1.0                        3.652174
# std                37.862989   0.0                        1.607209
# min                 4.000000   1.0                        2.000000
# 25%                26.720000   1.0                        2.000000
# 50%                32.300000   1.0                        4.000000
# 75%                56.240000   1.0                        4.000000
# max               232.300000   1.0                        8.000000
#
#        Кількість відгуків в гуглі  Количество чеков в месяц  Средний чек  \
# count                   39.000000                 69.000000    62.000000
# mean                    42.820513               7105.030583    95.897581
# std                     81.975565               4052.584218    19.192685
# ...

# %%
#drop useless columns
df = df.drop(['Этаж','Супермаркет'], axis='columns', inplace=False)
df.head(5)
# Out:
#    Площадь загальна кв.м  Количество сотрудников в штаті    Тип  \
# 0                    9.0                               2  Light
# 1                   30.0                               2  Light
# 2                   15.0                               2  light
# 3                   20.0                               2  light
# 4                   30.0                               2  light
#
#    Кількість відгуків в гуглі  Количество чеков в месяц  Средний чек  \
# 0                         NaN                    1230.0        76.85
# 1                         8.0                    2715.0        84.86
# 2                         NaN                     878.0       112.02
# 3                         NaN                    2346.0       119.80
# 4                         NaN                    2542.0        94.88
#
#    Середній дохід населення  Населення середнє  Спеціалізований хліб  \
# 0                   14910.0             3807.0                     1
# ...

# %%
df.columns
# Out:
# Index(['Площадь загальна кв.м', 'Количество сотрудников в штаті', 'Тип',
#        'Кількість відгуків в гуглі', 'Количество чеков в месяц', 'Средний чек',
#        'Середній дохід населення', 'Населення середнє', 'Спеціалізований хліб',
#        'Спеціалізоване м'ясо', 'Спеціалізований сир',
#        'Спеціалізована поб. Хімія'],
#       dtype='object')

# %%
#renaming columns
df.columns = ['площадь', 'количество_сотруд', 'тип',
       'гугл_отзывы', 'количество_чеков', 'ср_чек', 'ср_доход',
       'ср_население', 'спец_хлеб', 'спец_мясо','спец_сыр',
       'спец_хим']

# %%
# check missing
df.isnull().sum()
# Out:
# Площадь загальна кв.м              0
# Количество сотрудников в штаті     0
# Тип                                0
# Кількість відгуків в гуглі        30
# Количество чеков в месяц           0
# Средний чек                        7
# Середній дохід населення           5
# Населення середнє                  5
# Спеціалізований хліб               0
# Спеціалізоване м'ясо               0
# Спеціалізований сир                0
# Спеціалізована поб. Хімія          0
# dtype: int64

# %%
df.dtypes
# Out:
# площадь              float64
# количество_сотруд    float64
# тип                   object
# гугл_отзывы          float64
# количество_чеков     float64
# ср_чек               float64
# ср_доход             float64
# ср_население         float64
# спец_хлеб              int64
# спец_мясо              int64
# спец_сыр               int64
# спец_хим               int64
# dtype: object

# %%
#missing data is numeric, so let's recover it accordingly
#!pip install sklearn
dfm = df
from sklearn.impute import SimpleImputer
imputer_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
dfm[['Кількість відгуків в гуглі']] = imputer_mean.fit_transform(dfm[['Кількість відгуків в гуглі']]).round()
dfm[['Средний чек']] = imputer_mean.fit_transform(dfm[['Средний чек']]).round()
dfm[['Середній дохід населення']] = imputer_mean.fit_transform(dfm[['Середній дохід населення']]).round()
dfm[['Населення середнє']] = imputer_mean.fit_transform(dfm[['Населення середнє']]).round()

# %%
dfm.isnull().sum()
# Out:
# площадь              0
# количество_сотруд    0
# тип                  0
# гугл_отзывы          0
# количество_чеков     0
# ср_чек               0
# ср_доход             0
# ср_население         0
# спец_хлеб            0
# спец_мясо            0
# спец_сыр             0
# спец_хим             0
# dtype: int64

# %%
#encoding
dfs = df[['тип']]
info = []
for column in dfs.columns:
        vals = {"col": column,
                "nunique": dfs[column].nunique(),
                "unique": dfs[column].unique(),
                "type": dfs[column].dtype
               }
        info.append(vals)
pd.DataFrame(info).sort_values(by = "col", ascending = False)
# Out:
#    col  nunique                                    unique    type
# 0  тип        5  [Light, light, Standart, Micro, Premium]  object

# %%
type = {'Light':0,'light':0,'Standart':1,'Micro':2,'Premium':3}
df['тип'] = df['тип'].map(type)

# %%
df
# Out:
#     площадь  количество_сотруд  тип  гугл_отзывы  количество_чеков    ср_чек  \
# 0      9.00           0.693147    0         43.0            1230.0  1.468751
# 1     30.00           0.693147    0          8.0            2715.0  1.491251
# 2     15.00           0.693147    0         43.0             878.0  1.551491
# 3     20.00           0.693147    0         43.0            2346.0  1.566007
# 4     30.00           0.693147    0         43.0            2542.0  1.515979
# ..      ...                ...  ...          ...               ...       ...
# 64    51.77           1.791759    1          4.0           13552.0  1.541765
# 65    27.26           1.386294    0          3.0            7598.0  1.501549
# 66   148.91           0.693147    0         12.0            5431.0  1.539753
# 67    50.93           1.098612    1         17.0            4375.0  1.633928
# 68    30.00           1.098612    0         12.0            7355.0  1.531470
#
# ...

# %%
# Exporting the dataset
df.to_excel('19_prep2.xlsx', index=False)

# %%
#log
#!pip install seaborn
# Log Transformations for Skewed Distributions
dfm[['ср_чек']] = np.log(dfm[['ср_чек']])

# %%
import seaborn as sns
sns.set()
sns.pairplot(dfm)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-21a36716d241> in <module>
#       1 import seaborn as sns
#       2 sns.set()
# ----> 3 sns.pairplot(dfm)
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2107     if grid.square_grid:
#    2108         if diag_kind == "hist":
# -> 2109             grid.map_diag(plt.hist, **diag_kws)
#    2110         elif diag_kind == "kde":
#    2111             diag_kws.setdefault("shade", True)
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in map_diag(self, func, **kwargs)
#    1480                     data_k = utils.remove_na(data_k)
#    1481
# -> 1482                 func(data_k, label=label_k, color=color, **kwargs)
#    1483
# ...

# %%
dfm = df
# Outliers
площадь = []
for площадь in df['площадь']:
    if площадь > (df['площадь'].mean() + 3*df['площадь'].std()):
        площадь_м2 = (dfm['площадь'].mean() + 3*df['площадь'].std())
    elif площадь < (df['площадь'].mean() - 3*df['площадь'].std()):
        площадь = (dfm['площадь'].mean() - 3*df['площадь'].std())
    площадь.append(площадь)
df['площадь'] = площадь

количество_сотруд = []
for количество_сотруд in df['количество_сотруд']:
    if количество_сотруд > (df['количество_сотруд'].mean() + 3*df['количество_сотруд'].std()):
        количество_сотруд = (dfm['количество_сотруд'].mean() + 3*df['количество_сотруд'].std())
    elif количество_сотруд < (df['количество_сотруд'].mean() - 3*df['количество_сотруд'].std()):
        количество_сотруд = (dfm['количество_сотруд'].mean() - 3*df['количество_сотруд'].std())
    количество_сотруд.append(количество_сотруд)
df['количество_сотруд'] = количество_сотруд

гугл_отзывы = []
for гугл_отзывы in df['гугл_отзывы']:
    if гугл_отзывы > (df['гугл_отзывы'].mean() + 3*df['гугл_отзывы'].std()):
        гугл_отзывы = (dfm['гугл_отзывы'].mean() + 3*df['гугл_отзывы'].std())
    elif гугл_отзывы < (df['гугл_отзывы'].mean() - 3*df['гугл_отзывы'].std()):
        гугл_отзывы = (dfm['гугл_отзывы'].mean() - 3*df['гугл_отзывы'].std())
    гугл_отзывы_.append(гугл_отзывы)
df['гугл_отзывы'] = гугл_отзывы

количество_чеков = []
for количество_чеков in df['количество_чеков']:
    if количество_чеков > (df['количество_чеков'].mean() + 3*df['количество_чеков'].std()):
        количество_чеков = (dfm['количество_чеков'].mean() + 3*df['количество_чеков'].std())
    elif количество_чеков < (df['количество_чеков'].mean() - 3*df['количество_чеков'].std()):
        количество_чеков = (dfm['количество_чеков'].mean() - 3*df['количество_чеков'].std())
    количество_чеков.append(количество_чеков)
df['количество_чеков'] = количество_чеков
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-10b26c48dea5> in <module>
#       7     elif площадь < (df['площадь'].mean() - 3*df['площадь'].std()):
#       8         площадь = (dfm['площадь'].mean() - 3*df['площадь'].std())
# ----> 9     площадь.append(площадь)
#      10 df['площадь'] = площадь
#      11
#
# AttributeError: 'float' object has no attribute 'append'

# %%
df.describe()
# Out:
#           площадь  количество_сотруд        тип  гугл_отзывы  \
# count   69.000000          69.000000  69.000000    69.000000
# mean    47.412725           1.200565   0.347826    42.898551
# std     37.862989           0.440237   0.589768    61.280489
# min      4.000000           0.693147   0.000000     1.000000
# 25%     26.720000           0.693147   0.000000    12.000000
# 50%     32.300000           1.386294   0.000000    43.000000
# 75%     56.240000           1.386294   1.000000    43.000000
# max    232.300000           2.079442   3.000000   367.000000
#
#        количество_чеков     ср_чек   ср_доход  ср_население  спец_хлеб  \
# count         69.000000  69.000000  69.000000     69.000000  69.000000
# mean        7105.030583   1.513817       -inf   6061.289855   0.318841
# std         4052.584218   0.039046        NaN   4244.422753   0.469441
# min          878.000000   1.428968       -inf      0.000000   0.000000
# ...

# %%
sns.set()
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-dda1fb345d82> in <module>
#       1 sns.set()
# ----> 2 sns.pairplot(df)
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2107     if grid.square_grid:
#    2108         if diag_kind == "hist":
# -> 2109             grid.map_diag(plt.hist, **diag_kws)
#    2110         elif diag_kind == "kde":
#    2111             diag_kws.setdefault("shade", True)
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in map_diag(self, func, **kwargs)
#    1480                     data_k = utils.remove_na(data_k)
#    1481
# -> 1482                 func(data_k, label=label_k, color=color, **kwargs)
#    1483
#    1484             self._clean_axis(ax)
#
# ...

# %%
# Cheking correlations
import seaborn as sns
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, annot=True)
plt.show()

# %%
# Removing Correlated Data
df = df.drop(['спец_сыр'], axis='columns', inplace=False)
df = df.drop(['спец_хим'], axis='columns', inplace=False)
df = df.drop(['спец_мясо'], axis='columns', inplace=False)
df = df.drop(['спец_хлеб'], axis='columns', inplace=False)
df = df.drop(['тип'], axis='columns', inplace=False)
df.shape

# %%
a = ['площадь', 'гугл_отзывы', 'количество_чеков', 'ср_чек','ср_доход','ср_население']

# %%
#linear regression
#Splitting the dataset into the Training set and Test set
X =df[a]
y = df['количество_сотруд']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
# Fitting Simple Linear Regression to the Training set
f1 = ['количество_чеков']

from sklearn.linear_model import LinearRegression
sr = LinearRegression().fit(X_train[f1], y_train)

# Getting parameters
sr.coef_, sr.intercept_
# Out:
# (array([7.52357963e-05]), 0.6771078549644752)

# %%
# Predicting the Test set results
y_pred = sr.predict(X_test[f1])

# Coefficient of determination R^2
sr.score(X_train[f1], y_train).round(3), sr.score(X_test[f1], y_test).round(3)
# Out:
# (0.49, 0.656)

# %%
#49 % и 65,6% (для обучаемой и тестовой выборки) изменения показателя в ('количество_сотруд') можно обьяснить с помощью изменения Х. Остальные проценты - случайные факторы.

# %%
# Mean squared error
from sklearn.metrics import mean_squared_error
mean_squared_error(y_train, sr.predict(X_train[f1]), squared=False).round(2), mean_squared_error(y_test, y_pred, squared=False).round(2)
# Out:
# (0.32, 0.23)

# %%
# Visualising the Test set results
plt.scatter(X_test['количество_чеков'], y_test, color = 'red')
plt.plot(X_test['количество_чеков'], sr.predict(X_test[f1]), 'bo')
plt.title('количество_сотруд vs количество_чеков (Test set)')
plt.xlabel('количество_чеков')
plt.ylabel('количество_сотруд')
plt.show()

# %%
# Visualising the Test set results
plt.scatter(X_train['количество_чеков'], y_train, color = 'red')
plt.plot(X_train['количество_чеков'], sr.predict(X_train[f1]), 'bo')
plt.title('количество_сотруд vs количество_чеков (Test set)')
plt.xlabel('количество_чеков')
plt.ylabel('количество_сотруд')
plt.show()

# %%
#Multiple Linear Regression
#!pip install statsmodels

# %%
# Fitting Multiple Regression
mr = LinearRegression().fit(X_train, y_train)

# Coefficient of determination R^2
mr.score(X_train, y_train).round(3), mr.score(X_test, y_test).round(3)
# Out:
# (0.49, 0.654)

# %%
#коэф детерминации почти такие же, как у линейной

# %%
# Checking p-values
import statsmodels.api as sm
X1 = sm.add_constant(X_train)
mr1 = sm.OLS(y_train, X1).fit()
mr1.pvalues
# Out:
# const    0.000072
# x1       0.086993
# x2       0.966344
# dtype: float64

# %%
mr1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      количество_сотруд   R-squared:                       0.490
# Model:                            OLS   Adj. R-squared:                  0.471
# Method:                 Least Squares   F-statistic:                     25.03
# Date:                Tue, 19 Oct 2021   Prob (F-statistic):           2.43e-08
# Time:                        22:39:46   Log-Likelihood:                -14.628
# No. Observations:                  55   AIC:                             35.26
# Df Residuals:                      52   BIC:                             41.28
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6826      0.158      4.315      0.000       0.365       1.000
# ...

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
X_train_p = PolynomialFeatures().fit_transform(X_train)
X_test_p = PolynomialFeatures().fit_transform(X_test)

pr = LinearRegression().fit(X_train, y_train)

# Getting parameters
pr.coef_, pr.intercept_
# Out:
# (array([0.00000000e+00, 7.35070813e-05, 1.01532646e-10]), 0.6826204488058836)

# %%
pr = LinearRegression().fit(X_train, y_train)
# Predicting the Test set results
y_pred = pr.predict(X_test)

# Coefficient of determination R^2
pr.score(X_train, y_train).round(3), pr.score(X_test, y_test).round(3)
# Out:
# (0.49, 0.654)

# %%
pr = LinearRegression().fit(X_train, y_train)
# Mean squared error
mean_squared_error(y_train, pr.predict(X_train), squared=False).round(2), mean_squared_error(y_test, y_pred, squared=False).round(2)
# Out:
# (0.32, 0.23)

# %%
#Non-linear Regression
import pickle
obj = {'X_train': X_train, 'X_test': X_test,'y_train': y_train,'y_test': y_test}
output = open('data_reg.pkl', 'wb')
pickle.dump(obj, output, 2)
output.close()

# %%
input = open('data_reg.pkl', 'rb')
obj = pickle.load(input)
input.close()
X_train = obj["X_train"]
X_test = obj["X_test"]
y_train = obj["y_train"]
y_test = obj["y_test"]

f = ['количество_чеков', 'количество_сотруд']

# %%
# Metrics
def metrics(X_train, X_test, y_train, y_test, y_pred, model):
    RMSE = [mean_squared_error(y_train, model.predict(X_train),squared=False), mean_squared_error(y_test, y_pred, squared=False)]
    R2 = [model.score(X_train, y_train), model.score(X_test, y_test)]
    results = {'RMSE': RMSE, 'R2':R2}
    return pd.DataFrame(results, index=['Train', 'Test'])

# %%
#regression tree
def max_leaf_nodes(X_train, X_test, y_train, y_test, n):
    mse_train = []
    mse_test = []
    for i in n:
        dt = DecisionTreeRegressor(max_leaf_nodes = i, random_state=10).fit(X_train, y_train)
        mse_train.append(mean_squared_error(y_train, dt.predict(X_train)))
        mse_test.append(mean_squared_error(y_test, dt.predict(X_test)))
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.plot(n, mse_train, alpha=0.5, color='blue', label='train')
    ax.plot(n, mse_test, alpha=0.5, color='red', label='test')
    ax.set_ylabel("MSE")
    ax.set_xlabel("max_leaf_nodes")

# %%
# The optimal number of max_leaf_nodes
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
max_leaf_nodes(X_train, X_test, y_train, y_test, [2, 3, 4])

# %%
# Fitting Tree to the Training set
dt = DecisionTreeRegressor(max_leaf_nodes = 3).fit(X_train, y_train)

# Predicting the Test set results
dt_y_pred = dt.predict(X_test)

# Metrics
metrics(X_train, X_test, y_train, y_test, dt_y_pred, dt).round(2)
# Out:
#        RMSE    R2
# Train  0.29  0.57
# Test   0.25  0.60

# %%
#random forest
def rf_best_n_estimator(X_train, X_test, y_train, y_test, n):
    mse_train = []
    mse_test = []
    for i in n:
        rf = RandomForestRegressor(n_estimators=i, random_state=10).fit(X_train, y_train)
        mse_train.append(mean_squared_error(y_train, rf.predict(X_train)))
        mse_test.append(mean_squared_error(y_test, rf.predict(X_test)))
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.plot(n, mse_train, alpha=0.5, color='blue', label='train')
    ax.plot(n, mse_test, alpha=0.5, color='red', label='test')
    ax.set_ylabel("MSE")
    ax.set_xlabel("N_estimators")
    
# The optimal number of trees 
from sklearn.ensemble import RandomForestRegressor    
rf_best_n_estimator(X_train, X_test, y_train, y_test, [2, 5, 10, 13, 17, 20, 25])

# %%
def rf_max_leaf_nodes(X_train, X_test, y_train, y_test, n):
    mse_train = []
    mse_test = []
    for i in n:
        rf = RandomForestRegressor(n_estimators=2, max_leaf_nodes =i, random_state=10).fit(X_train, y_train)
        mse_train.append(mean_squared_error(y_train, rf.predict(X_train)))
        mse_test.append(mean_squared_error(y_test, rf.predict(X_test)))
    fig, ax = plt.subplots(figsize=(8, 4))
    ax.plot(n, mse_train, alpha=0.5, color='blue', label='train')
    ax.plot(n, mse_test, alpha=0.5, color='red', label='test')
    ax.set_ylabel("MSE")
    ax.set_xlabel("max_leaf_nodes")
    
# The optimal number of max_leaf_nodes
rf_max_leaf_nodes(X_train, X_test, y_train, y_test, [20, 25, 30, 35, 40])

# %%
# Fitting Random Forest to the Training set
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 2, max_leaf_nodes = 25, random_state = 10).fit(X_train, y_train)

# Predicting the Test set results
rf_y_pred = rf.predict(X_test)

# Metrics
metrics(X_train, X_test, y_train, y_test, rf_y_pred, rf).round(2)
# Out:
#        RMSE    R2
# Train  0.19  0.81
# Test   0.51 -0.70

# %%
#random forest is the best because of R2
